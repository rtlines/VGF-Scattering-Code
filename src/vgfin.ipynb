# %%
import numpy as np
import cmath as cm
from collections import Counter

W = float(input("Enter the wavelength: "))
NSID = int(input("Enter the number of dipoles along the major axes: "))
NLSID = int(input("Enter the number of fine structure devisions per dipole cell side: "))
RAD = float(input("Enter the particle symmetry semi-axes (z-axes radius): "))
alpha = float(input("Enter the incident theta (in degrees): "))
beta = float(input("Enter the value for phi (in degrees): "))
gamma = float(input("Enter the value for gamma (in degrees): "))
psi = float(input("Enter the polarization angle (in degrees): "))
MR = float(input("Enter the real part of the the index of refraction: "))
MI = float(input("Enter the imaginary part of the index of refraction: "))
AR = float(input("Enter the aspect ratio (major axis/minor axis): "))             
COMMENTS = float(input("Enter the file comments: "))
OUTFILE = float(input("Enter the output filename: "))

def SD(W,MI):
    if MI = 0:
        SD = 0
    else:
        SD = (W/(2*np.pi*MI))
    return SD

Max = max(RAD, (RAD/AR))

TD = ((2*Max)/NSID)

if MI < 0:
    MI = -MI
M = complex(MR,MI)

DRF = 0.5*(NSID - 1)

LD = TD/NLSID

FRAC = 1/NLSID

NUSE = 0



for NISD in range(0,20 ):
    for i in range (0, NISD-1):
        xi = (i - DRF)TD
        yi = (i - DRF)TD
        zi = (i - DRF)TD
        for NLSID in range (0,20):
            for j in range (0, NLSID - 1):
                xj = (j - DRF)TD
                yj = (j - DRF)TD
                zj = (j - DRF)TD
                
                RF(1) = xi + LD*(0.5*(1.0 - NLSID) + xj)      
                RF(2) = yi + LD*(0.5*(1.0 - NLSID) + yj)
                RF(3) = zi + LD*(0.5*(1.0 - NLSID) + zj)
                
                def INSIDE (RAD,RF,AR,SD):
                    return np.sqrt((RF(1)/(RAD**2/AR**2)) + np.sqrt((RF(2)/(RAD**2/AR**2)) + np.sqrt(RF(2)/RAD**2)))
                if 1 < INSIDE:
                    return yes
                else:
                    return no
                INCNT = Counter(yes)
                
D = TD*(INCNT/(NLSID**3))**(1/3)
print (D)
